# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud

df = pd.read_csv('Salary_Data.csv')

# %%
print("\nTop 5 Occupations")
df["Job Title"].value_counts().nlargest(5)
# Out:
# Top 5 Occupations
# Software Engineer            518
# Data Scientist               453
# Software Engineer Manager    376
# Data Analyst                 363
# Senior Project Engineer      318
# Name: Job Title, dtype: int64

# %%
job_title = df['Job Title'].tolist()
print(type(job_title))
print(job_title)
# Out:
# <class 'list'>
# ...

# %%
dr_count = {i:job_title.count(i) for i in job_title}
print(dr_count)
# Out:
# {'Software Engineer': 518, 'Data Analyst': 363, 'Senior Manager': 2, 'Sales Associate': 70, 'Director': 1, 'Marketing Analyst': 132, 'Product Manager': 313, 'Sales Manager': 56, 'Marketing Coordinator': 158, 'Senior Scientist': 3, 'Software Developer': 125, 'HR Manager': 2, 'Financial Analyst': 39, 'Project Manager': 22, 'Customer Service Rep': 1, 'Operations Manager': 114, 'Marketing Manager': 255, 'Senior Engineer': 2, 'Data Entry Clerk': 1, 'Sales Director': 63, 'Business Analyst': 2, 'VP of Operations': 1, 'IT Support': 1, 'Recruiter': 2, 'Financial Manager': 134, 'Social Media Specialist': 1, 'Software Manager': 1, 'Junior Developer': 1, 'Senior Consultant': 1, 'Product Designer': 75, 'CEO': 1, 'Accountant': 1, 'Data Scientist': 453, 'Marketing Specialist': 1, 'Technical Writer': 1, 'HR Generalist': 2, 'Project Engineer': 1, 'Customer Success Rep': 1, 'Sales Executive': 38, 'UX Designer': 1, 'Operations Director': 1, 'Network Engineer': 1, 'Administrative Assistant': 2, 'Strateg
# ...

# %%
from collections import Counter

dr_count = {i: job_title.count(i) for i in job_title}

# Use Counter to get the top 20 frequencies
counter_object = Counter(dr_count)
top_125 = dict(counter_object.most_common(125))

print(top_125)
# Out:
# {'Software Engineer': 518, 'Data Scientist': 453, 'Software Engineer Manager': 376, 'Data Analyst': 363, 'Senior Project Engineer': 318, 'Product Manager': 313, 'Full Stack Engineer': 309, 'Marketing Manager': 255, 'Senior Software Engineer': 244, 'Back end Developer': 244, 'Front end Developer': 241, 'Marketing Coordinator': 158, 'Junior Sales Associate': 142, 'Financial Manager': 134, 'Marketing Analyst': 132, 'Software Developer': 125, 'Operations Manager': 114, 'Human Resources Manager': 104, 'Director of Marketing': 88, 'Web Developer': 87, 'Product Designer': 75, 'Research Director': 75, 'Content Marketing Manager': 73, 'Sales Associate': 70, 'Research Scientist': 69, 'Senior Product Marketing Manager': 69, 'Director of HR': 69, 'Marketing Director': 64, 'Sales Director': 63, 'Senior Data Scientist': 61, 'Junior HR Generalist': 60, 'Junior Software Developer': 58, 'Director of Data Science': 57, 'Receptionist': 57, 'Sales Manager': 56, 'Digital Marketing Manager': 52, 'Junior M
# ...

# %%
mask = np.array(Image.open("trophy.png"))

wordcloud = WordCloud(
    background_color="white", 
    mask = mask,
    contour_color ='steelblue',
)
wordcloud.generate_from_frequencies(top_125)

# %%
plt.imshow(wordcloud)
plt.axis("off")
plt.figure(figsize=(10,10))
plt.show()
